# %% [markdown]
# ## Preprocess OSM into parquets

# %% [markdown]
# ## Embeddings for semantic search

# %%
import pandas as pd
import geopandas as gpd

df = gpd.read_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\natural.parquet")

# %%
df
# Out:
#               lat         lon        natural  \
# 0       37.144093 -121.984710         saddle
# 1       34.204039 -117.808757         saddle
# 2       41.738128 -121.529074        volcano
# 3       41.728373 -121.548889  cave_entrance
# 4       37.865539 -122.243419          stone
# ...           ...         ...            ...
# 852648        NaN         NaN          scree
# 852649        NaN         NaN          scrub
# 852650        NaN         NaN      bare_rock
# 852651        NaN         NaN          scrub
# 852652        NaN         NaN          scrub
#
#                                                  geometry
# 0                             POINT (-121.98471 37.14409)
# 1                             POINT (-117.80876 34.20404)
# 2                             POINT (-121.52907 41.73813)
# 3                             POINT (-121.54889 41.72837)
# 4                             POINT (-122.24342 37.86554)
# ...                                                   ...
# 852648  MULTIPOLYGON (((-119.87783 39.34051, -119.8778...
# 852649  MULTIPOLYGON (((-119.94491 39.05863, -119.9449...
# 852650  MULTIPOLYGON (((-119.94509 39.05859, -119.9450...
# 852651  MULTIPOLYGON (((-119.94477 39.0774, -119.94485...
# 852652  POLYGON ((-119.94023 39.07078, -119.94024 39.0...
#
# [852653 rows x 4 columns]

# %%
unique_classes = [str(i) for i in df.dropna(subset=['natural']).natural.unique()]

# %%
print(len(unique_classes), unique_classes)
# Out:
# 117 ['saddle', 'volcano', 'cave_entrance', 'stone', 'peak', 'tree', 'spring', 'cliff', 'rock', 'hot_spring', 'cape', 'wood', 'bay', 'arch', 'rock_formation', 'beach', 'water', 'crater', 'geyser', 'sinkhole', 'hill', 'slope', 'heath', 'wetland', 'desert', 'plateau', 'tree_stump', 'grassland', 'valley', 'point', 'scrub', 'scree', 'canyon', 'ridge', 'dune', 'yes', 'bush', 'ravine', 'grove', 'mountain_range', 'shrub', 'flat', 'wildflowers', 'succulent_plant', 'cactus', 'flowering_plant', 'bare_rock', 'geothermal_area', 'cirque', 'plant', 'landform', 'birds_nest', 'peninsula', 'mesa', 'grass', 'butte', 'basin', 'stump', 'sediment', 'hills', 'plain', 'depression', 'cave', 'caldera', 'fumarole', 'agave', 'coastline', 'shingle', 'reef', 'sand', 'mud', 'fell', 'shrubbery', 'wadi', 'dry wash', 'strait', 'glacier', 'knoll', 'gully', 'gorge', 'dry_wash', 'shoal', 'tree_row', 'mountain_basin', 'lava', 'fault', 'range', 'landslide', 'shrubland', 'arete', 'meadow', 'tree_group', 'land', 'boulder', 'dry_lake', 'ground', 'soil', 'earth_bank', 'greenery', 'lake', 'dirt', 'floodplain', 'anthill', 'trees', 'forest', 'blowout', 'desert_pavement', 'massif', 'marsh', 'gulch', 'shoreline', 'fissure', 'rocks', 'transform_fault', 'feature', 'playa', 'water;wetland']

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer

# 2. Load the all-MiniLM-L6-v2 model
model = SentenceTransformer("all-MiniLM-L6-v2")

# 3. Generate embeddings (convert to Python lists for clean Parquet serialization)
embeddings = model.encode(unique_classes, convert_to_numpy=True).tolist()

# 4. Construct the pandas DataFrame matching your target structure
df = pd.DataFrame({"amenities": unique_classes, "embedding": embeddings})

# 5. Save to a Parquet file
parquet_filename = rf"E:\Data\query-earth\embeddings\osm\2026\poi_semnatic.parquet"
df.to_parquet(parquet_filename, index=False)

print(f"Successfully saved {len(df)} embeddings to '{parquet_filename}'.")
print("\nFirst 2 rows preview:")
print(df.head(2))
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Successfully saved 584 embeddings to 'E:\Data\query-earth\embeddings\osm\2026\poi_semnatic.parquet'.
#
# First 2 rows preview:
#   amenities                                          embedding
# 0      bank  [0.00487261638045311, 0.025024818256497383, -0...
# 1   toilets  [0.0520838238298893, 0.03292398899793625, 0.00...

# %%
pd.read_parquet(rf"D:\Code\query-earth\src\embeddings\poi_embeddings.parquet")
# Out:
#            amenities                                          embedding
# 0             stream  [-0.049106162, -0.041543964, -0.053305697, -0....
# 1         borderland  [0.08206559, 0.03463122, -0.08410268, -0.00889...
# 2              knoll  [-0.014341307, -0.033093102, 0.040650368, -0.0...
# 3             canyon  [0.0007149489, 0.018037673, -0.036527846, 0.05...
# 4               park  [0.04683362, 0.033664923, 0.028864298, -0.0315...
# ..               ...                                                ...
# 714          massage  [-0.06918556, 0.015118147, 0.037174415, 0.0665...
# 715    feeding_place  [0.006678588, 0.00031741234, -0.055687092, 0.0...
# 716           mikveh  [-0.11270124, 0.083171666, 0.008068371, 0.0276...
# 717       makerspace  [-0.05816774, -0.078223355, 0.011646609, 0.029...
# 718  animal_grooming  [-0.066686906, 0.012551327, 0.07692128, 0.0469...
#
# [719 rows x 2 columns]

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# 1. Load the Parquet file and the model
df = pd.read_parquet(parquet_filename)
model = SentenceTransformer("all-MiniLM-L6-v2")

# 2. Define your search query and top-K count
search_query = "emergency serives"
top_k = 15

# 3. Generate embedding for the search query
query_embedding = model.encode([search_query], convert_to_numpy=True)

# 4. Calculate cosine similarity against stored embeddings
stored_embeddings = df["embedding"].tolist()
similarities = cosine_similarity(query_embedding, stored_embeddings)[0]

# 5. Add similarity scores to DataFrame and retrieve top K results
df["similarity"] = similarities
top_results = df.nlargest(top_k, "similarity")[["amenities", "similarity"]]

# Display results
print(f"Top {top_k} results for query: '{search_query}'\n")
print(top_results.to_string(index=False))
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Top 15 results for query: 'emergency serives'
#
#                                amenities  similarity
#                              urgent_care    0.484460
#                            air_ambulance    0.479867
#                                 hospital    0.430942
#                         first_aid_school    0.412686
#                                first_aid    0.398327
#                              crematorium    0.388058
#                      fire_station;prison    0.376305
#                                  service    0.370967
#                                   prison    0.370141
#                       crematory_services    0.367695
#                                  toilets    0.359046
#                                     stor    0.354631
#                           disused:clinic    0.354610
#                                      spa    0.349121
# assisted_living;skilled_nursing_facility    0.345494

# %% [markdown]
# ### Appdx

# %%
import os
import gc
from pyrosm import OSM

# Paths
pbf_path = r"E:\Data\query-earth\osm\california-latest.osm.pbf"
output_dir = r"E:\Data\query-earth\osm\2026"

# Create output folder if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Initialize OSM parser
osm = OSM(pbf_path)

# # --- 1. BUILDINGS ---
# print("Extracting buildings...")
# buildings = osm.get_buildings()
# if buildings is not None and not buildings.empty:
#     out_path = os.path.join(output_dir, "buildings.parquet")
#     print(f"Saving to {out_path}...")
#     buildings.to_parquet(out_path, compression="snappy")
#     del buildings
#     gc.collect()

# # --- 2. LANDUSE ---
# print("Extracting landuse...")
# landuse = osm.get_landuse()
# if landuse is not None and not landuse.empty:
#     out_path = os.path.join(output_dir, "landuse.parquet")
#     print(f"Saving to {out_path}...")
#     landuse.to_parquet(out_path, compression="snappy")
#     del landuse
#     gc.collect()

# # --- 3. NATURAL FEATURES ---
# print("Extracting natural features...")
# natural = osm.get_natural()
# if natural is not None and not natural.empty:
#     out_path = os.path.join(output_dir, "natural.parquet")
#     print(f"Saving to {out_path}...")
#     natural.to_parquet(out_path, compression="snappy")
#     del natural
#     gc.collect()

# # --- 4. ROADS & NETWORKS ---
# print("Extracting roads...")
# roads = osm.get_network(network_type="all")
# if roads is not None and not roads.empty:
#     out_path = os.path.join(output_dir, "roads.parquet")
#     print(f"Saving to {out_path}...")
#     roads.to_parquet(out_path, compression="snappy")
#     del roads
#     gc.collect()

# # --- 5. WATERWAYS ---
# print("Extracting waterways...")
# waterways = osm.get_data_by_custom_criteria(custom_filter={"waterway": True})
# if waterways is not None and not waterways.empty:
#     out_path = os.path.join(output_dir, "waterways.parquet")
#     print(f"Saving to {out_path}...")
#     waterways.to_parquet(out_path, compression="snappy")
#     del waterways
#     gc.collect()

boundaries = osm.get_boundaries()
if boundaries is not None and not boundaries.empty:
    out_path = os.path.join(output_dir, "boundaries.parquet")
    print(f"Saving to {out_path}...")
    boundaries.to_parquet(out_path, compression="snappy")
    del boundaries
    gc.collect()
# Out:
# Saving to E:\Data\query-earth\osm\2026\boundaries.parquet...

# %%
import geopandas as gpd
boundaries = gpd.read_parquet(out_path)

# %%
boundaries[boundaries['boundary']=="preotected_area"]
# Out:
# Empty GeoDataFrame
# Columns: [addr:city, addr:country, addr:housenumber, addr:postcode, addr:street, name, operator, phone, ref, visible, website, admin_level, boundary, border_type, start_date, id, timestamp, version, tags, osm_type, geometry, changeset]
# Index: []
#
# [0 rows x 22 columns]

# %%
boundaries
# Out:
#      addr:city addr:country addr:housenumber addr:postcode addr:street  \
# 0          NaN          NaN              NaN           NaN         NaN
# 1          NaN          NaN              NaN           NaN         NaN
# 2          NaN          NaN              NaN           NaN         NaN
# 3          NaN          NaN              NaN           NaN         NaN
# 4          NaN          NaN              NaN           NaN         NaN
# ...        ...          ...              ...           ...         ...
# 2331       NaN          NaN              NaN           NaN         NaN
# 2332       NaN          NaN              NaN           NaN         NaN
# 2333       NaN          NaN              NaN           NaN         NaN
# 2334       NaN          NaN              NaN           NaN         NaN
# 2335       NaN          NaN              NaN           NaN         NaN
#
#                    name operator phone  ref visible  ...        boundary  \
# 0                   NaN      NaN   NaN  NaN   False  ...  administrative
# 1                   NaN      NaN   NaN  NaN   False  ...  administrative
# 2        Naples Islands      NaN   NaN  NaN   False  ...  administrative
# 3     Circle of Freedom      NaN   NaN  NaN   False  ...  administrative
# 4                   NaN      NaN   NaN  NaN   False  ...  administrative
# ...                 ...      ...   ...  ...     ...  ...             ...
# 2331           Romoland      NaN   NaN  NaN    None  ...  administrative
# 2332             Clovis      NaN   NaN  NaN    None  ...  administrative
# 2333       Quail Valley      NaN   NaN  NaN    None  ...  administrative
# 2334         Cottonwood      NaN   NaN  NaN    None  ...  administrative
# 2335    Sunrise Estates      NaN   NaN  NaN    None  ...  administrative
#
#      border_type start_date        id   timestamp  version  \
# 0            NaN        NaN  14337188  1379164237        2
# 1            NaN        NaN  14337553  1780951430        5
# 2            NaN        NaN  23944308  1732729033       14
# 3            NaN        NaN  24026033  1578080313        4
# 4            NaN        NaN  29473390  1784928242       12
# ...          ...        ...       ...         ...      ...
# 2331         NaN        NaN  20412569  1775387803        2
# 2332         NaN        NaN  20517351  1776784845        1
# 2333         NaN        NaN  20576264  1777081440        3
# 2334         NaN        NaN  20613059  1777675790        1
# 2335         NaN        NaN  20613060  1777675790        1
#
#                                                    tags  osm_type  \
# 0     {"tiger:cfcc":"A51","tiger:county":"Lincoln, N...       way
# 1     {"tiger:cfcc":"A51","tiger:county":"Lincoln, N...       way
# 2     {"natural":"coastline","nist:fips_code":"037",...       way
# 3                          {"boundary_type":"national"}       way
# 4                                                   NaN       way
# ...                                                 ...       ...
# 2331  {"type":"boundary","wikidata":"Q2026167","wiki...  relation
# 2332  {"type":"boundary","members":[{"member_id":331...  relation
# 2333  {"type":"boundary","wikidata":"Q2547023","wiki...  relation
# 2334  {"type":"boundary","members":[{"member_id":150...  relation
# 2335  {"type":"boundary","members":[{"member_id":150...  relation
#
#                                                geometry changeset
# 0     MULTILINESTRING ((-115.75254 37.51142, -115.75...       NaN
# 1     MULTILINESTRING ((-115.88212 37.5483, -115.881...       NaN
# 2     POLYGON ((-118.12959 33.75686, -118.12956 33.7...       NaN
# 3     POLYGON ((-122.25931 37.86945, -122.2593 37.86...       NaN
# 4     POLYGON ((-123.29313 40.00284, -123.29342 40.0...       NaN
# ...                                                 ...       ...
# 2331  POLYGON ((-117.18937 33.73574, -117.18935 33.7...       0.0
# 2332  POLYGON ((-119.68852 36.86683, -119.68957 36.8...       0.0
# 2333  POLYGON ((-117.25814 33.71387, -117.25803 33.6...       0.0
# 2334  POLYGON ((-119.31333 36.18601, -119.31338 36.1...       0.0
# 2335  POLYGON ((-119.31433 36.17685, -119.31247 36.1...       0.0
#
# [2336 rows x 22 columns]

# %%
boundaries.boundary
# Out:
# 0       MULTIPOINT ((-115.7526 37.5011), (-115.75254 3...
# 1       MULTIPOINT ((-115.88212 37.5483), (-115.75254 ...
# 2       LINESTRING (-118.12959 33.75686, -118.12956 33...
# 3       LINESTRING (-122.25931 37.86945, -122.2593 37....
# 4       LINESTRING (-123.29313 40.00284, -123.29342 40...
#                               ...
# 2331    LINESTRING (-117.18937 33.73574, -117.18935 33...
# 2332    LINESTRING (-119.68852 36.86683, -119.68957 36...
# 2333    LINESTRING (-117.25814 33.71387, -117.25803 33...
# 2334    LINESTRING (-119.31333 36.18601, -119.31338 36...
# 2335    LINESTRING (-119.31433 36.17685, -119.31247 36...
# Length: 2336, dtype: geometry

# %%
# --- 7. PROTECTED AREAS & PARKS ---
print("Extracting protected areas, national parks, and reserves...")
# Captures national parks, nature reserves, protected areas, and wildlife sanctuaries
protected_filter = {
    "boundary": ["protected_area", "national_park"],
    "leisure": ["nature_reserve", "park"],
    "protected_class": True
}
protected_areas = osm.get_data_by_custom_criteria(custom_filter=protected_filter)
# Out:
# Extracting protected areas, national parks, and reserves...

# %%
protected_areas.columns
# Out:
# Index(['timestamp', 'changeset', 'visible', 'lon', 'version', 'id', 'lat',
#        'tags', 'addr:city', 'addr:country', 'addr:housenumber',
#        'addr:postcode', 'addr:street', 'email', 'name', 'opening_hours',
#        'operator', 'phone', 'url', 'website', 'boundary', 'protected_area',
#        'leisure', 'geometry', 'osm_type', 'addr:full', 'addr:housename',
#        'addr:place', 'ref', 'admin_level', 'maritime', 'start_date', 'fishing',
#        'park', 'picnic_table', 'pitch', 'playground', 'swimming_pool'],
#       dtype='str')

# %%
protected_areas.name
# Out:
# 0                 Mendota Wildlife Management Area
# 1                                     Hidden Palms
# 2        Marconi Conference Center & Historic Park
# 3                                 Saratoga Springs
# 4           Salt Springs Waterfowl Management Area
#                            ...
# 22569                                          NaN
# 22570                                          NaN
# 22571                               RDA Winchester
# 22572                           Abelia Sports Park
# 22573                              Brookfield Park
# Name: name, Length: 22574, dtype: str

# %%
protected_areas = protected_areas[["geometry"]]
protected_areas['landuse'] = "protected area"

# %%
protected_areas.to_parquet("protect.parquet")

# %%
# --- 8. FORESTS & WOODLANDS ---
print("Extracting forests and natural woodlands...")
# Captures designated forestry land as well as natural wood/forest areas
forest_filter = {
    "landuse": ["forest"],
    "natural": ["wood"]
}
forests = osm.get_data_by_custom_criteria(custom_filter=forest_filter)
# Out:
# Extracting forests and natural woodlands...

# %%
forests["landuse"] = forests["natural"].combine_first(forests["landuse"])

# %%
forests=forests[['landuse', 'geometry']]

# %%
gdf = gpd.read_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\landuse.parquet")

# %%
gdf
# Out:
#         lat  lon       landuse  \
# 6763    NaN  NaN    industrial
# 6764    NaN  NaN  construction
# 6765    NaN  NaN       railway
# 6766    NaN  NaN    industrial
# 6767    NaN  NaN      farmland
# ...     ...  ...           ...
# 518351  NaN  NaN     flowerbed
# 518352  NaN  NaN        forest
# 518353  NaN  NaN        forest
# 518354  NaN  NaN        retail
# 518355  NaN  NaN   residential
#
#                                                  geometry
# 6763    POLYGON ((-117.091 33.11698, -117.09079 33.116...
# 6764    POLYGON ((-122.25784 37.86529, -122.25629 37.8...
# 6765    POLYGON ((-117.69417 35.03426, -117.69401 35.0...
# 6766    POLYGON ((-120.75512 39.0125, -120.75493 39.01...
# 6767    POLYGON ((-120.21416 35.51073, -120.21407 35.5...
# ...                                                   ...
# 518351  POLYGON ((-118.3829 34.09067, -118.38289 34.09...
# 518352  POLYGON ((-122.58719 40.64945, -122.58714 40.6...
# 518353  MULTIPOLYGON (((-119.86363 39.35022, -119.8638...
# 518354  POLYGON ((-115.13135 36.19588, -115.13122 36.1...
# 518355  MULTIPOLYGON (((-119.94765 39.07799, -119.9476...
#
# [511558 rows x 4 columns]

# %%
import pandas as pd

combined_gdf = pd.concat([gdf, protected_areas], ignore_index=True)
combined_gdf = pd.concat([combined_gdf, forests], ignore_index=True)

# %%
combined_gdf.to_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\landuse.parquet")

# %%
def prepare_gdf_for_parquet(gdf):
    """Converts mixed object columns (like 'id') to string to avoid PyArrow serialization errors."""
    if gdf is None or gdf.empty:
        return gdf
    
    # Cast the 'id' column explicitly to string if present
    if "id" in gdf.columns:
        gdf["id"] = gdf["id"].astype(str)
        
    # Convert any other object/mixed columns (excluding geometry) to string type
    for col in gdf.select_dtypes(include=["object"]).columns:
        if col != gdf._geometry_column_name:
            gdf[col] = gdf[col].astype(str)
            
    return gdf
    
# 6. POINTS OF INTEREST (POIs)
print("Extracting POIs...")
pois = prepare_gdf_for_parquet(
    osm.get_pois(
        custom_filter={
            "amenity": True,
            "shop": True,
            "leisure": True,
            "tourism": True,
            "place": True
        }
    )
)
if pois is not None:
    out_path = os.path.join(output_dir, "pois.parquet")
    print(f"Saving to {out_path}...")
    pois.to_parquet(out_path, compression="snappy")
    del pois
    gc.collect()

print("\nAll layers successfully extracted and saved as GeoParquet files.")
# Out:
# Extracting POIs...
# C:\Users\sus14836\AppData\Local\Temp\ipykernel_41376\3674067905.py:11: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in gdf.select_dtypes(include=["object"]).columns:
# Saving to E:\Data\query-earth\osm\2026\pois.parquet...
#
# All layers successfully extracted and saved as GeoParquet files.

# %% [markdown]
# ### Landuse

# %%
import pandas as pd
import geopandas as gpd

df = gpd.read_parquet(rf"E:\Data\query-earth\osm\2026\landuse.parquet")

# %%
df
# Out:
#               lat   timestamp  version visible         lon  changeset  \
# 0       35.325313  1510540681        5   False -120.727476        0.0
# 1       35.325196  1510540681        4   False -120.727364        0.0
# 2       38.617960  1692739405        4   False -121.400786        0.0
# 3       34.071124  1756101978        4   False -117.181427        0.0
# 4       40.776775  1738211854        2   False -122.283016        0.0
# ...           ...         ...      ...     ...         ...        ...
# 518351        NaN  1784660365        1    None         NaN        0.0
# 518352        NaN  1784662801        1    None         NaN        0.0
# 518353        NaN  1784682964        1    None         NaN        0.0
# 518354        NaN  1784941843        1    None         NaN        0.0
# 518355        NaN  1784953733        1    None         NaN        0.0
#
#                id                                               tags  \
# 0        91597312                               {"access":"private"}
# 1        91597369                               {"access":"private"}
# 2       150954852  {"ele":"20","gnis:feature_id":"1660019","name"...
# 3       150980949  {"ele":"419","gnis:feature_id":"1839597","name...
# 4       320120937  {"name":"Shasta Iron Mine","wikidata":"Q494479...
# ...           ...                                                ...
# 518351   21127188  {"type":"multipolygon","members":[{"member_id"...
# 518352   21127290  {"type":"multipolygon","members":[{"member_id"...
# 518353   21128146  {"ownership":"county","type":"multipolygon","m...
# 518354   21141560  {"type":"multipolygon","members":[{"member_id"...
# 518355   21142070  {"type":"multipolygon","members":[{"member_id"...
#
#        construction depot  ... commercial farmland farmyard grass meadow  \
# 0               NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 1               NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 2               NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 3               NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 4               NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# ...             ...   ...  ...        ...      ...      ...   ...    ...
# 518351          NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 518352          NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 518353          NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 518354          NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 518355          NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
#
#        quarry railway recreation_ground retail orchard
# 0         NaN     NaN               NaN    NaN     NaN
# 1         NaN     NaN               NaN    NaN     NaN
# 2         NaN     NaN               NaN    NaN     NaN
# 3         NaN     NaN               NaN    NaN     NaN
# 4         NaN     NaN               NaN    NaN     NaN
# ...       ...     ...               ...    ...     ...
# 518351    NaN     NaN               NaN    NaN     NaN
# 518352    NaN     NaN               NaN    NaN     NaN
# 518353    NaN     NaN               NaN    NaN     NaN
# 518354    NaN     NaN               NaN    NaN     NaN
# 518355    NaN     NaN               NaN    NaN     NaN
#
# [518356 rows x 30 columns]

# %%
df = df[['lat', 'lon', 'landuse', 'geometry']]

# %%
df[df.geometry.geom_type.isin(['Polygon', 'MultiPolygon'])].to_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\landuse.parquet")

# %% [markdown]
# ### Buildings

# %%
import pandas as pd
import geopandas as gpd

df = gpd.read_parquet(rf"E:\Data\query-earth\osm\2026\buildings.parquet")

# %%
df = df[['amenity', 'name', 'geometry']]

# %%
df
# Out:
#          amenity      name                                           geometry
# 0            NaN  Hangar 1  POLYGON ((-122.05507 37.4141, -122.05508 37.41...
# 1            NaN       NaN  POLYGON ((-117.5651 33.42527, -117.5651 33.425...
# 2            NaN       NaN  POLYGON ((-117.45199 34.42306, -117.45191 34.4...
# 3            NaN       NaN  POLYGON ((-117.52246 34.41063, -117.52254 34.4...
# 4            NaN       NaN  POLYGON ((-117.50382 34.40248, -117.50394 34.4...
# ...          ...       ...                                                ...
# 10277113     NaN       NaN  MULTIPOLYGON (((-120.98514 38.70054, -120.9851...
# 10277114     NaN   Augie's  POLYGON ((-119.6978 34.41905, -119.69786 34.41...
# 10277115     NaN       NaN  POLYGON ((-122.49725 37.74987, -122.49723 37.7...
# 10277116     NaN       NaN  POLYGON ((-117.21069 33.93341, -117.21069 33.9...
# 10277117     NaN       NaN  POLYGON ((-117.21069 33.93341, -117.21056 33.9...
#
# [10277118 rows x 3 columns]

# %%
df.to_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\buildings.parquet")

# %% [markdown]
# ### Natural

# %%
import pandas as pd
import geopandas as gpd

df = gpd.read_parquet(rf"E:\Data\query-earth\osm\2026\natural.parquet")

# %%
df
# Out:
#               lat   timestamp  version visible         lon  changeset  \
# 0       37.144093  1676333776       50   False -121.984710        0.0
# 1       34.204039  1609808614        7   False -117.808757        0.0
# 2       41.738128  1506287239        5   False -121.529074        0.0
# 3       41.728373  1738129819        3   False -121.548889        0.0
# 4       37.865539  1691917308        5   False -122.243419        0.0
# ...           ...         ...      ...     ...         ...        ...
# 852648        NaN  1784682964        1    None         NaN        0.0
# 852649        NaN  1784920941        1    None         NaN        0.0
# 852650        NaN  1784920941        1    None         NaN        0.0
# 852651        NaN  1784953733        1    None         NaN        0.0
# 852652        NaN  1784994671        1    None         NaN        0.0
#
#               id                                               tags  \
# 0       26497399  {"ele":"548","mountain_pass":"yes","name":"Pat...
# 1       26794832                     {"name":"Horse Canyon Saddle"}
# 2       33113071  {"ele":"1618","name":"Schonchin Butte","volcan...
# 3       33113431  {"created_by":"JOSM","name":"Merrill Ice Cave"...
# 4       34351134          {"name":"The Rock","tourism":"viewpoint"}
# ...          ...                                                ...
# 852648  21128147  {"ownership":"national","type":"multipolygon",...
# 852649  21140696  {"ownership":"national","type":"multipolygon",...
# 852650  21140697  {"ownership":"national","type":"multipolygon",...
# 852651  21142069  {"ownership":"private","type":"multipolygon","...
# 852652  21143398  {"ownership":"state","type":"multipolygon","me...
#
#               natural peak  ... beach grassland reef sand scrub stone  \
# 0              saddle  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 1              saddle  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 2             volcano  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 3       cave_entrance  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 4               stone  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# ...               ...  ...  ...   ...       ...  ...  ...   ...   ...
# 852648          scree  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 852649          scrub  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 852650      bare_rock  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 852651          scrub  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 852652          scrub  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
#
#        tree_row wood rock valley
# 0           NaN  NaN  NaN    NaN
# 1           NaN  NaN  NaN    NaN
# 2           NaN  NaN  NaN    NaN
# 3           NaN  NaN  NaN    NaN
# 4           NaN  NaN  NaN    NaN
# ...         ...  ...  ...    ...
# 852648      NaN  NaN  NaN    NaN
# 852649      NaN  NaN  NaN    NaN
# 852650      NaN  NaN  NaN    NaN
# 852651      NaN  NaN  NaN    NaN
# 852652      NaN  NaN  NaN    NaN
#
# [852653 rows x 27 columns]

# %%
# 1. Ensure natural column is string, drop NaNs if needed
has_no_digits = (
    df['natural']
    .fillna('')
    .astype(str)
    .str.contains(r'\d', regex=True) == False
)

# 2. Filter out empty strings/NaNs (optional, depending on whether you want to keep missing natural values)
has_value = df['natural'].notna() & (df['natural'] != '')

# 3. Apply filter
df = df[has_no_digits & has_value].copy()

# %%
df
# Out:
#               lat   timestamp  version visible         lon  changeset  \
# 0       37.144093  1676333776       50   False -121.984710        0.0
# 1       34.204039  1609808614        7   False -117.808757        0.0
# 2       41.738128  1506287239        5   False -121.529074        0.0
# 3       41.728373  1738129819        3   False -121.548889        0.0
# 4       37.865539  1691917308        5   False -122.243419        0.0
# ...           ...         ...      ...     ...         ...        ...
# 852648        NaN  1784682964        1    None         NaN        0.0
# 852649        NaN  1784920941        1    None         NaN        0.0
# 852650        NaN  1784920941        1    None         NaN        0.0
# 852651        NaN  1784953733        1    None         NaN        0.0
# 852652        NaN  1784994671        1    None         NaN        0.0
#
#               id                                               tags  \
# 0       26497399  {"ele":"548","mountain_pass":"yes","name":"Pat...
# 1       26794832                     {"name":"Horse Canyon Saddle"}
# 2       33113071  {"ele":"1618","name":"Schonchin Butte","volcan...
# 3       33113431  {"created_by":"JOSM","name":"Merrill Ice Cave"...
# 4       34351134          {"name":"The Rock","tourism":"viewpoint"}
# ...          ...                                                ...
# 852648  21128147  {"ownership":"national","type":"multipolygon",...
# 852649  21140696  {"ownership":"national","type":"multipolygon",...
# 852650  21140697  {"ownership":"national","type":"multipolygon",...
# 852651  21142069  {"ownership":"private","type":"multipolygon","...
# 852652  21143398  {"ownership":"state","type":"multipolygon","me...
#
#               natural peak  ... beach grassland reef sand scrub stone  \
# 0              saddle  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 1              saddle  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 2             volcano  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 3       cave_entrance  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 4               stone  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# ...               ...  ...  ...   ...       ...  ...  ...   ...   ...
# 852648          scree  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 852649          scrub  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 852650      bare_rock  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 852651          scrub  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
# 852652          scrub  NaN  ...   NaN       NaN  NaN  NaN   NaN   NaN
#
#        tree_row wood rock valley
# 0           NaN  NaN  NaN    NaN
# 1           NaN  NaN  NaN    NaN
# 2           NaN  NaN  NaN    NaN
# 3           NaN  NaN  NaN    NaN
# 4           NaN  NaN  NaN    NaN
# ...         ...  ...  ...    ...
# 852648      NaN  NaN  NaN    NaN
# 852649      NaN  NaN  NaN    NaN
# 852650      NaN  NaN  NaN    NaN
# 852651      NaN  NaN  NaN    NaN
# 852652      NaN  NaN  NaN    NaN
#
# [852653 rows x 27 columns]

# %%
df[['lat', 'lon', 'natural', 'geometry']].to_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\natural.parquet")

# %% [markdown]
# ### POI

# %%
import pandas as pd
import geopandas as gpd

df = gpd.read_parquet(rf"E:\Data\query-earth\osm\2026\pois.parquet")

# %%
df = df[['lat', 'lon', 'amenity', 'name', 'geometry']]

# %%
condition = df['name'].notna() | df['amenity'].notna()
result_df = df.loc[condition, ['lat', 'lon', 'amenity', 'name', 'geometry']]

# %%
result_df
# Out:
#               lat         lon amenity                     name  \
# 0       34.948373 -116.864611     NaN        Calico Ghost Town
# 1       36.701463 -118.755997     NaN               California
# 2       36.979368 -122.020726    bank                    Chase
# 3       33.977685 -118.448647     NaN           Marina del Rey
# 4       33.995044 -118.466887     NaN                   Venice
# ...           ...         ...     ...                      ...
# 969157        NaN         NaN     NaN  North Las Vegas Gateway
# 969160        NaN         NaN     NaN          Hemet Golf Club
# 969162        NaN         NaN     NaN           RDA Winchester
# 969163        NaN         NaN     NaN       Abelia Sports Park
# 969164        NaN         NaN     NaN          Brookfield Park
#
#                                                  geometry
# 0                             POINT (-116.86461 34.94837)
# 1                               POINT (-118.756 36.70146)
# 2                             POINT (-122.02073 36.97937)
# 3                             POINT (-118.44865 33.97768)
# 4                             POINT (-118.46689 33.99504)
# ...                                                   ...
# 969157  MULTIPOLYGON (((-115.13483 36.19594, -115.1344...
# 969160  POLYGON ((-117.05567 33.74986, -117.0566 33.75...
# 969162  MULTIPOLYGON (((-117.1075 33.60751, -117.10679...
# 969163  POLYGON ((-117.10123 33.61639, -117.10123 33.6...
# 969164  POLYGON ((-117.10293 33.61498, -117.10295 33.6...
#
# [669063 rows x 5 columns]

# %%
result_df.to_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\pois.parquet")

# %% [markdown]
# ### Roads

# %%
gpd.read_parquet(rf"E:\Data\query-earth\embeddings\osm\2014\natural.parquet")
# Out:
#               lat         lon        natural  \
# 0       41.738128 -121.529074           peak
# 1       41.728373 -121.548889  cave_entrance
# 2       41.731862 -121.523006  cave_entrance
# 3       41.733325 -121.526261  cave_entrance
# 4       41.731126 -121.510769  cave_entrance
# ...           ...         ...            ...
# 161147        NaN         NaN          water
# 161148        NaN         NaN          water
# 161149        NaN         NaN          water
# 161150        NaN         NaN          water
# 161151        NaN         NaN          water
#
#                                                  geometry
# 0                             POINT (-121.52907 41.73813)
# 1                             POINT (-121.54889 41.72837)
# 2                             POINT (-121.52301 41.73186)
# 3                             POINT (-121.52626 41.73332)
# 4                             POINT (-121.51077 41.73113)
# ...                                                   ...
# 161147  POLYGON ((-120.49727 39.28691, -120.49725 39.2...
# 161148  POLYGON ((-120.50379 39.28144, -120.50379 39.2...
# 161149  POLYGON ((-121.78459 38.52861, -121.78467 38.5...
# 161150  POLYGON ((-121.67757 38.5431, -121.6777 38.543...
# 161151  POLYGON ((-119.99764 38.43069, -119.99736 38.4...
#
# [160314 rows x 4 columns]

# %%
import pandas as pd
import geopandas as gpd

df = gpd.read_parquet(rf"E:\Data\query-earth\osm\2026\roads.parquet")

# %%
df.highway.unique()
# Out:
# <ArrowStringArray>
# [          'service',          'motorway',       'residential',
#              'track',          'tertiary',           'primary',
#       'primary_link',         'secondary',     'motorway_link',
#       'unclassified',            'busway',             'trunk',
#     'secondary_link',             'steps',           'footway',
#           'cycleway',        'trunk_link',              'path',
#      'living_street',        'pedestrian',     'tertiary_link',
#          'bridleway',              'road',  'residential_link',
#              'minor',      'turning_loop',          'corridor',
#           'elevator',     'emergency_bay',          'bus_stop',
#       'service;path',            'escape',           'disused',
#       'bus_guideway',       'via_ferrata',          'crossing',
#     'traffic_island',     'passing_place',          'scramble',
#           'footpath',            'ladder',    'turning_circle',
#  'footway:abandoned']
# Length: 43, dtype: str

# %%
df[["highway", "geometry"]].to_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\roads.parquet")

# %% [markdown]
# ### Waterways

# %%
import pandas as pd
import geopandas as gpd

df = gpd.read_parquet(rf"E:\Data\query-earth\osm\2026\waterways.parquet")

# %%
df
# Out:
#               lat   timestamp  version visible         lon  changeset  \
# 0       34.195230  1735753246       36   False -118.601831        0.0
# 1       34.139095  1351286856        4   False -115.120558        0.0
# 2       33.896622  1769737191        6   False -117.586105        0.0
# 3       36.145761  1766407508        2   False -114.416950        0.0
# 4       37.727553  1694886109       16   False -119.543748        0.0
# ...           ...         ...      ...     ...         ...        ...
# 972364        NaN  1779837918        1    None         NaN        0.0
# 972365        NaN  1784206454        7    None         NaN        0.0
# 972366        NaN  1784237544        1    None         NaN        0.0
# 972367        NaN  1784416506        3    None         NaN        0.0
# 972368        NaN  1784471481        1    None         NaN        0.0
#
#                id                                               tags dock  \
# 0        36395349  {"description":"The nominal (name only) source...  NaN
# 1        54283836                                                NaN  NaN
# 2        54478232  {"access":"yes","barrier":"gate","gate:type":"...  NaN
# 3       158798380                                                NaN  NaN
# 4       243671668  {"alt_name":"Yonapah","ele":"1538","height":"9...  NaN
# ...           ...                                                ...  ...
# 972364   20750416  {"name":"Caldwell Creek","type":"waterway","me...  NaN
# 972365   21106986  {"name":"Bear River","type":"waterway","wikida...  NaN
# 972366   21108733  {"name":"Big River","type":"waterway","wikidat...  NaN
# 972367   21116252  {"name":"Gage Canal","type":"waterway","wikida...  NaN
# 972368   21117978  {"name":"Bull Creek","type":"waterway","wikida...  NaN
#
#        water_point waterfall    waterway  \
# 0              NaN       NaN  confluence
# 1              NaN       NaN        weir
# 2              NaN       NaN   floodgate
# 3              NaN       NaN  confluence
# 4              NaN       NaN   waterfall
# ...            ...       ...         ...
# 972364         NaN       NaN      stream
# 972365         NaN       NaN       river
# 972366         NaN       NaN       river
# 972367         NaN       NaN       canal
# 972368         NaN       NaN      stream
#
#                                                  geometry  osm_type  dam  \
# 0                             POINT (-118.60183 34.19523)      node  NaN
# 1                             POINT (-115.12056 34.13909)      node  NaN
# 2                             POINT (-117.58611 33.89662)      node  NaN
# 3                             POINT (-114.41695 36.14576)      node  NaN
# 4                             POINT (-119.54375 37.72755)      node  NaN
# ...                                                   ...       ...  ...
# 972364  LINESTRING (-118.33841 35.78525, -118.33833 35...  relation  NaN
# 972365  MULTILINESTRING ((-124.07594 40.38425, -124.07...  relation  NaN
# 972366  LINESTRING (-123.38128 39.31517, -123.38183 39...  relation  NaN
# 972367  MULTILINESTRING ((-117.33622 33.97197, -117.33...  relation  NaN
# 972368  MULTILINESTRING ((-124.0341 40.31428, -124.034...  relation  NaN
#
#        drain stream
# 0        NaN    NaN
# 1        NaN    NaN
# 2        NaN    NaN
# 3        NaN    NaN
# 4        NaN    NaN
# ...      ...    ...
# 972364   NaN    NaN
# 972365   NaN    NaN
# 972366   NaN    NaN
# 972367   NaN    NaN
# 972368   NaN    NaN
#
# [972369 rows x 17 columns]

# %%
pd.read_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\waterway.parquet")
# Out:
#           waterway                                           geometry
# 0       confluence  b'\x01\x01\x00\x00\x00\xda.~d\x84\xa6]\xc0s\xd...
# 1             weir  b'\x01\x01\x00\x00\x00[\xd1\xe68\xb7\xc7\\\xc0...
# 2        floodgate  b'\x01\x01\x00\x00\x004!\xf7\xbe\x82e]\xc0\xe3...
# 3       confluence  b'\x01\x01\x00\x00\x00M\x84\rO\xaf\x9a\\\xc0!\...
# 4        waterfall  b'\x01\x01\x00\x00\x00\xd3\xd1\xbb\xc2\xcc\xe2...
# ...            ...                                                ...
# 972364      stream  b'\x01\x02\x00\x00\x00\xa0\x01\x00\x00n+b}\xa8...
# 972365       river  b'\x01\x05\x00\x00\x00\x02\x00\x00\x00\x01\x02...
# 972366       river  b'\x01\x02\x00\x00\x00\x16\x04\x00\x00\x96\x8b...
# 972367       canal  b'\x01\x05\x00\x00\x00\x02\x00\x00\x00\x01\x02...
# 972368      stream  b'\x01\x05\x00\x00\x00\r\x00\x00\x00\x01\x02\x...
#
# [972369 rows x 2 columns]

# %%
df[['waterway', 'geometry']].to_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\waterway.parquet")

# %% [markdown]
# ---

# %% [markdown]
# ## Appdx

# %%
import os

os.listdir(rf"E:\Data\query-earth\embeddings\osm\2026")
# Out:
# ['buildings.parquet',
#  'landuse.parquet',
#  'natural.parquet',
#  'pois.parquet',
#  'poi_semnatic.parquet',
#  'roads.parquet',
#  'waterway.parquet']

# %% [markdown]
# buildings
# natural
# pois
#
#
# landuse
#
#
# waterway
#
#
# roads

# %%
import pandas as pd

df = pd.read_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\buildings.parquet")

# %%
df
# Out:
#          amenity      name                                           geometry
# 0            NaN  Hangar 1  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x1f\x00...
# 1            NaN       NaN  b"\x01\x03\x00\x00\x00\x01\x00\x00\x00\x14\x00...
# 2            NaN       NaN  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# 3            NaN       NaN  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\n\x00\x...
# 4            NaN       NaN  b"\x01\x03\x00\x00\x00\x01\x00\x00\x00\r\x00\x...
# ...          ...       ...                                                ...
# 10277113     NaN       NaN  b'\x01\x06\x00\x00\x00\x05\x00\x00\x00\x01\x03...
# 10277114     NaN   Augie's  b"\x01\x03\x00\x00\x00\x02\x00\x00\x00\x05\x00...
# 10277115     NaN       NaN  b'\x01\x03\x00\x00\x00\x02\x00\x00\x00&\x00\x0...
# 10277116     NaN       NaN  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x0e\x00...
# 10277117     NaN       NaN  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
#
# [10277118 rows x 3 columns]

# %%
import pandas as pd
import geopandas as gps

df = gpd.read_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\landuse.parquet")
df.landuse.unique()
# Out:
# <ArrowStringArray>
# [            'industrial',           'construction',                'railway',
#                'farmland',                'orchard',             'commercial',
#                  'retail',            'residential',                 'quarry',
#                'cemetery',
#  ...
#                'tree_pit',                  'scrub',                'lodging',
#        'orchard;vineyard',           'governmental',           'public_works',
#                    'sign',              'rangeland', 'commercial;residential',
#                'facility']
# Length: 141, dtype: str

# %%
import pandas as pd

df = pd.read_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\natural.parquet")
df.natural.unique()
# Out:
# <ArrowStringArray>
# [         'saddle',         'volcano',   'cave_entrance',           'stone',
#             'peak',            'tree',          'spring',           'cliff',
#             'rock',      'hot_spring',
#  ...
#           'massif',           'marsh',           'gulch',       'shoreline',
#          'fissure',           'rocks', 'transform_fault',         'feature',
#            'playa',   'water;wetland']
# Length: 117, dtype: str

# %%
import pandas as pd

df = pd.read_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\waterway.parquet")
df.waterway.unique()
# Out:
# <ArrowStringArray>
# [           'confluence',                  'weir',             'floodgate',
#              'waterfall', 'sanitary_dump_station',                   'dam',
#              'lock_gate',                  'fuel',                'rapids',
#                   'dock',       'pumping_station',            'stream_end',
#                  'ditch',                'switch',            'surge_tank',
#           'flow_control',          'access_point',                  'bend',
#            'sluice_gate',                   'bay',                   'yes',
#            'water_point',                 'drain',         'turning_point',
#              'boat_lift',               'cascade',                'stream',
#                'fairway',              'boatyard',                 'valve',
#          'tidal_channel',                 'flume',              'flowline',
#          'debris_screen',                 'canal',           'pressurised',
#                  'river',             'check_dam',            'artificial',
#                   'duct',                  'wadi',      'floating_barrier',
#              'fish_pass',                  'wash',        'derelict_canal',
#           'construction',                  'link',             'drystream',
#            'pressurized',           'fish_screen',              'spillway',
#                   'vadi']
# Length: 52, dtype: str

# %%
import pandas as pd
import geopandas as gpd

df = gpd.read_parquet(rf"E:\Data\query-earth\embeddings\osm\2026\pois.parquet")
df.amenity.unique()
# Out:
# <ArrowStringArray>
# [                            nan,                          'bank',
#                        'toilets',                'drinking_water',
#                        'parking',              'parking_entrance',
#                          'bench',                        'studio',
#                      'fast_food',                           'pub',
#  ...
#                         'cabana',                       'planter',
#                   'registration',                     'reception',
#                     'egg-laying',                  'event_center',
#  'charging_station;charge_point',    'place_of_worship;monastery',
#  'childcare;kindergarten;school',                     'cafe;fuel']
# Length: 585, dtype: str

# %%
df[df['landuse']=="nature reserve"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df[df['landuse']=="nature reserve"]
#
# NameError: name 'df' is not defined

# %%
l = df.landuse.unique()

# %%
l
# Out:
# <ArrowStringArray>
# [            'industrial',           'construction',                'railway',
#                'farmland',                'orchard',             'commercial',
#                  'retail',            'residential',                 'quarry',
#                'cemetery',
#  ...
#                'tree_pit',                  'scrub',                'lodging',
#        'orchard;vineyard',           'governmental',           'public_works',
#                    'sign',              'rangeland', 'commercial;residential',
#                'facility']
# Length: 141, dtype: str

# %%
for i in l:
    print(i)
# Out:
# industrial
# construction
# railway
# farmland
# orchard
# commercial
# retail
# residential
# quarry
# cemetery
# recreation_ground
# greenfield
# basin
# grass
# allotments
# reservoir
# demolished:recreation_ground
# brownfield
# farmyard
# institutional
# forest
# farm
# landfill
# religious
# military
# education
# village_green
# meadow
# vineyard
# salt_pond
# fairground
# residential;monument;historic_site
# ranch
# plant_nursery
# foreign_trade_zone
# greenhouse_horticulture
# public
# utility
# government
# telescope
# special_use
# public_facility
# prisons
# civic_admin
# railway;commercial
# winter_sports
# recreation_ground;landuse=fairground
# nature reserve
# traffic_island
# nature_reserve
# observatory
# garages
# civil
# commercial;retail
# aquaculture
# animal_keeping
# corral
# nursery
# shrubland
# salt_desert
# municipial
# depot
# civic
# weigh_station
# flowerbed
# logistics
# temp
# transportation
# ruins
# wasteland
# dirt
# greenery
# oilfield
# oil_field
# public_building
# water_storage
# storage
# quad
# conservation
# vacant
# gravel
# pasture
# desert
# community_food_growing
# apiary
# yes
# nature
# moving_building
# disused:industrial
# Maintenance Area
# civic_services
# judicial
# community garden
# open_space
# civic_safety
# training_area
# harbour
# airfield
# highway
# transport
# garden
# park
# proposed
# cerro
# civic_service
# Storm Drain overflow basin
# sand
# turf
# recreation
# homeless camp
# unknown
# paddleboat
# public facility
# radio
# eduation
# Luch Tables
# unpatented_mining_claim
# paved
# school
# mixed
# private
# parking
# shrubs
# tourism
# wholesale
# healthcare
# putting green
# rail
# special use
# easement
# mine
# tree_pit
# scrub
# lodging
# orchard;vineyard
# governmental
# public_works
# sign
# rangeland
# commercial;residential
# facility

# %%
df[df['landuse']=="conservation"].to_file(rf"cons.shp")

# %%
df
# Out:
#         lat  lon       landuse  \
# 6763    NaN  NaN    industrial
# 6764    NaN  NaN  construction
# 6765    NaN  NaN       railway
# 6766    NaN  NaN    industrial
# 6767    NaN  NaN      farmland
# ...     ...  ...           ...
# 518351  NaN  NaN     flowerbed
# 518352  NaN  NaN        forest
# 518353  NaN  NaN        forest
# 518354  NaN  NaN        retail
# 518355  NaN  NaN   residential
#
#                                                  geometry
# 6763    POLYGON ((-117.091 33.11698, -117.09079 33.116...
# 6764    POLYGON ((-122.25784 37.86529, -122.25629 37.8...
# 6765    POLYGON ((-117.69417 35.03426, -117.69401 35.0...
# 6766    POLYGON ((-120.75512 39.0125, -120.75493 39.01...
# 6767    POLYGON ((-120.21416 35.51073, -120.21407 35.5...
# ...                                                   ...
# 518351  POLYGON ((-118.3829 34.09067, -118.38289 34.09...
# 518352  POLYGON ((-122.58719 40.64945, -122.58714 40.6...
# 518353  MULTIPOLYGON (((-119.86363 39.35022, -119.8638...
# 518354  POLYGON ((-115.13135 36.19588, -115.13122 36.1...
# 518355  MULTIPOLYGON (((-119.94765 39.07799, -119.9476...
#
# [511558 rows x 4 columns]

# %%
import os
import gc
from pyrosm import OSM

# Paths
pbf_path = r"E:\Data\query-earth\osm\california-latest.osm.pbf"
output_dir = r"E:\Data\query-earth\osm\2026"

# Create output folder if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Initialize OSM parser
osm = OSM(pbf_path)

# --- 2. LANDUSE ---
print("Extracting landuse...")
landuse = osm.get_landuse()
# Out:
# Extracting landuse...

# %%
landuse
# Out:
#          timestamp  changeset visible         lon  version         id  \
# 0       1510540681        0.0   False -120.727476        5   91597312
# 1       1510540681        0.0   False -120.727364        4   91597369
# 2       1692739405        0.0   False -121.400786        4  150954852
# 3       1756101978        0.0   False -117.181427        4  150980949
# 4       1738211854        0.0   False -122.283016        2  320120937
# ...            ...        ...     ...         ...      ...        ...
# 518351  1784660365        0.0     NaN         NaN        1   21127188
# 518352  1784662801        0.0     NaN         NaN        1   21127290
# 518353  1784682964        0.0     NaN         NaN        1   21128146
# 518354  1784941843        0.0     NaN         NaN        1   21141560
# 518355  1784953733        0.0     NaN         NaN        1   21142070
#
#               lat                                               tags  \
# 0       35.325313                               {"access":"private"}
# 1       35.325196                               {"access":"private"}
# 2       38.617960  {"ele":"20","gnis:feature_id":"1660019","name"...
# 3       34.071124  {"ele":"419","gnis:feature_id":"1839597","name...
# 4       40.776775  {"name":"Shasta Iron Mine","wikidata":"Q494479...
# ...           ...                                                ...
# 518351        NaN  {"type":"multipolygon","members":[{"member_id"...
# 518352        NaN  {"type":"multipolygon","members":[{"member_id"...
# 518353        NaN  {"ownership":"county","type":"multipolygon","m...
# 518354        NaN  {"type":"multipolygon","members":[{"member_id"...
# 518355        NaN  {"type":"multipolygon","members":[{"member_id"...
#
#        construction depot  ... commercial farmland farmyard grass meadow  \
# 0               NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 1               NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 2               NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 3               NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 4               NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# ...             ...   ...  ...        ...      ...      ...   ...    ...
# 518351          NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 518352          NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 518353          NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 518354          NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
# 518355          NaN   NaN  ...        NaN      NaN      NaN   NaN    NaN
#
#        quarry railway recreation_ground retail orchard
# 0         NaN     NaN               NaN    NaN     NaN
# 1         NaN     NaN               NaN    NaN     NaN
# 2         NaN     NaN               NaN    NaN     NaN
# 3         NaN     NaN               NaN    NaN     NaN
# 4         NaN     NaN               NaN    NaN     NaN
# ...       ...     ...               ...    ...     ...
# 518351    NaN     NaN               NaN    NaN     NaN
# 518352    NaN     NaN               NaN    NaN     NaN
# 518353    NaN     NaN               NaN    NaN     NaN
# 518354    NaN     NaN               NaN    NaN     NaN
# 518355    NaN     NaN               NaN    NaN     NaN
#
# [518356 rows x 30 columns]

# %%
landuse.columns
# Out:
# Index(['timestamp', 'changeset', 'visible', 'lon', 'version', 'id', 'lat',
#        'tags', 'construction', 'depot', 'industrial', 'landuse', 'military',
#        'residential', 'geometry', 'osm_type', 'allotments', 'basin',
#        'brownfield', 'cemetery', 'commercial', 'farmland', 'farmyard', 'grass',
#        'meadow', 'quarry', 'railway', 'recreation_ground', 'retail',
#        'orchard'],
#       dtype='str')

# %%
landuse[['osm_type', 'landuse']]
# Out:
#         osm_type      landuse
# 0           node     military
# 1           node     military
# 2           node       retail
# 3           node  residential
# 4           node       quarry
# ...          ...          ...
# 518351  relation    flowerbed
# 518352  relation       forest
# 518353  relation       forest
# 518354  relation       retail
# 518355  relation  residential
#
# [518356 rows x 2 columns]

# %%
landuse[landuse['landuse'].isin(["nature reserve", "nature_reserve", "conservation"])][1:].to_file(rf"cons.shp")
# Out:
# C:\Users\sus14836\AppData\Local\Temp\ipykernel_49436\2165323771.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   landuse[landuse['landuse'].isin(["nature reserve", "nature_reserve", "conservation"])][1:].to_file(rf"cons.shp")
# d:\Code\esri-earth-search-engine\env\Lib\site-packages\pyogrio\raw.py:733: RuntimeWarning: Normalized/laundered field name: 'construction' to 'constructi'
#   ogr_write(
# d:\Code\esri-earth-search-engine\env\Lib\site-packages\pyogrio\raw.py:733: RuntimeWarning: Normalized/laundered field name: 'residential' to 'residentia'
#   ogr_write(
# d:\Code\esri-earth-search-engine\env\Lib\site-packages\pyogrio\raw.py:733: RuntimeWarning: Normalized/laundered field name: 'recreation_ground' to 'recreation'
#   ogr_write(
# d:\Code\esri-earth-search-engine\env\Lib\site-packages\pyogrio\raw.py:733: RuntimeWarning: Value '{"AREAID":"110457420756","COUNTYFP":"007","MTFCC":"K2180","STATEFP":"06","Tiger:MTFCC":"K2180","name":"Oroville Wildlife Management Area","source":"Tiger2009","tiger:ALAND":"3646396","tiger:AWATER":"0","tiger:reviewed":"no","type":"multipolygon","members":[{"member_id":44389882,"member_type":"way","member_role":"outer"},{"member_id":44389872,"member_type":"way","member_role":"inner"}]}' of field tags has been truncated to 254 characters.  This warning will not be emitted any more for that layer.
#   ogr_write(

# %%
landuse[landuse['landuse'].isin(["nature reserve", "nature_reserve", "conservation"])][['landuse', 'geometry']]
# Out:
#                landuse                                           geometry
# 6093      conservation                         POINT (-119.1337 37.97709)
# 15369   nature reserve  POLYGON ((-117.18632 32.79567, -117.18712 32.7...
# 16183   nature_reserve  POLYGON ((-119.7175 39.43091, -119.71753 39.43...
# 230290    conservation  POLYGON ((-120.61825 35.13274, -120.6183 35.13...
# 231971    conservation  POLYGON ((-122.41337 40.49854, -122.41378 40.4...
# 231972    conservation  POLYGON ((-122.41736 40.50058, -122.41724 40.5...
# 231973    conservation  POLYGON ((-122.43125 40.49588, -122.43114 40.4...
# 231974    conservation  POLYGON ((-122.41718 40.50102, -122.41739 40.5...
# 231975    conservation  POLYGON ((-122.42539 40.49804, -122.42562 40.4...
# 231976    conservation  POLYGON ((-122.42295 40.50017, -122.42325 40.5...
# 238075    conservation  POLYGON ((-120.62435 35.13085, -120.62454 35.1...
# 238084    conservation  POLYGON ((-120.61824 35.13283, -120.61808 35.1...
# 238086    conservation  POLYGON ((-120.61213 35.13076, -120.61264 35.1...
# 276804    conservation  POLYGON ((-122.54405 38.13192, -122.54509 38.1...
# 276807    conservation  POLYGON ((-122.53258 38.1232, -122.53257 38.12...
# 276808    conservation  POLYGON ((-122.53057 38.12297, -122.53089 38.1...
# 507923  nature_reserve  POLYGON ((-121.63877 39.43068, -121.63881 39.4...
# 510401  nature_reserve  POLYGON ((-118.28693 34.22165, -118.28636 34.2...
